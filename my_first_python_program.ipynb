# %%
print("num1")
print("num2")
Num1 = 10
Num2 = 3
# Out:
# num1
# num2

# %%
print (Num1+Num2)
# Out:
# 13

# %%
Sum = Num1 + Num2
print (sum)

# %%
print (Sum + Num1)
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 5, 10)
y = np.sin(x)
plt.plot(x, y)
plt.show(2)

plt.plot(x, np.sin(x))
plt.show(5)
# Out:
# 23
